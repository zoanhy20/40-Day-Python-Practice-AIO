# %% [markdown]
# <a href="https://colab.research.google.com/github/zoanhy20/40-Day-Python-Practice-AIO/blob/main/40_Day_Python_Practice_Day_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
lst_data = [1, 1.1, None, 1.4, None, 1.5, None, 2.0]

idx_none = [idx for idx, value in enumerate(lst_data) if value == None]

print(f'Vị trí None đầu tiên: {idx_none[0]} - Danh sách vị trí có giá trị None: {idx_none}')
# Out:
# Vị trí None đầu tiên: 2 - Danh sách vị trí có giá trị None: [2, 4, 6]
